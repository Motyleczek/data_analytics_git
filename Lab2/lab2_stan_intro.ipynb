# %%
from cmdstanpy import CmdStanModel
import pandas as pd
import arviz as az 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

F = 6
L = 5

# %% [markdown]
# # Ex. 1. Generated Quantities Block

# %% [markdown]
# 1. Complile `code_1.stan` and sample from it using M=F.

# %%
gen_quant = CmdStanModel(stan_file='code_1.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
samples = gen_quant.sample(data={'M':F}, 
                            fixed_param=True, 
                            iter_sampling=1000, 
                            iter_warmup=0, 
                            chains = 1)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
samples_df = samples.draws_pd()

# %%
samples_df.head()
# Out:
#    lp__  accept_stat__    lambda  y_sim[1]  y_sim[2]  y_sim[3]  y_sim[4]  \
# 0   0.0            0.0  105.5360     109.0      99.0     102.0     105.0
# 1   0.0            0.0   17.9225      22.0      21.0      16.0      23.0
# 2   0.0            0.0  112.1260     109.0      99.0     106.0     109.0
# 3   0.0            0.0  123.7770     114.0     109.0     110.0     137.0
# 4   0.0            0.0   34.5088      28.0      41.0      40.0      32.0
#
#    y_sim[5]  y_sim[6]
# 0     104.0     107.0
# 1      13.0      17.0
# 2     108.0     110.0
# 3     135.0     108.0
# 4      45.0      41.0

# %% [markdown]
# 3. plot a histogram of each of lambda and y_sim.

# %%
sns.histplot(data=samples_df, x="lambda")
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15,10))

sns.histplot(data=samples_df, x="y_sim[1]", ax=axs[0, 0])
sns.histplot(data=samples_df, x="y_sim[2]", ax=axs[0, 1])
sns.histplot(data=samples_df, x="y_sim[3]", ax=axs[0, 2])
sns.histplot(data=samples_df, x="y_sim[4]", ax=axs[1, 0])
sns.histplot(data=samples_df, x="y_sim[5]", ax=axs[1, 1])
sns.histplot(data=samples_df, x="y_sim[6]", ax=axs[1, 2])

plt.show()

# %% [markdown]
# # Ex. 2. Coinstraints on the data
#
# Observe how constraints on data behave for `code_2.stan` and `code_3.stan`

# %%
bern1 = CmdStanModel(stan_file='code_2.stan')
samp_bern1 = bern1.sample(data={'N':2, 'y':[0,1]})
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
#
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
#
# chain 3 |██████████| 00:00 Sampling completed
#
#
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
bern2 = CmdStanModel(stan_file='code_3.stan')
samp_bern2 = bern2.sample(data={'N':2, 'y':[0,1]})
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▍         | 00:00 Status
#
#
#
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %% [markdown]
# With insufficient data constraints stan will not work properly.
#
# # Ex. 3. Constraints on parameters
#
# Unconstrained parameters

# %%
model_gm1 = CmdStanModel(stan_file='code_4.stan')
out_gamma1 = model_gm1.sample(output_dir='samples',iter_sampling=6000,iter_warmup=1000, seed=4838282)
out_gamma1.diagnose()
# Out:
# INFO:cmdstanpy:compiling stan file /home/Lab2/code_4.stan to exe file /home/Lab2/code_4
# INFO:cmdstanpy:compiled model executable: /home/Lab2/code_4
# INFO:cmdstanpy:created output directory: /home/Lab2/samples
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |█▋        | 00:00 Iteration: 1000 / 7000 [ 14%]  (Warmup)
#
#
#
#
#
# chain 1 |██▎       | 00:05 Iteration: 1400 / 7000 [ 20%]  (Sampling)
#
#
# chain 1 |██▊       | 00:07 Iteration: 1700 / 7000 [ 24%]  (Sampling)
# chain 1 |███       | 00:09 Iteration: 1900 / 7000 [ 27%]  (Sampling)
#
#
#
# chain 1 |███▎      | 00:10 Iteration: 2100 / 7000 [ 30%]  (Sampling)
# chain 1 |███▍      | 00:11 Iteration: 2200 / 7000 [ 31%]  (Sampling)
#
# chain 1 |███▌      | 00:12 Iteration: 2300 / 7000 [ 32%]  (Sampling)
#
#
# chain 1 |███▊      | 00:13 Iteration: 2400 / 7000 [ 34%]  (Sampling)
#
#
# chain 1 |███▉      | 00:14 Iteration: 2500 / 7000 [ 35%]  (Sampling)
#
#
# chain 1 |████      | 00:15 Iteration: 2600 / 7000 [ 37%]  (Sampling)
#
#
# chain 1 |████▏     | 00:15 Iteration: 2700 / 7000 [ 38%]  (Sampling)
#
#
# chain 1 |████▎     | 00:16 Iteration: 2800 / 7000 [ 40%]  (Sampling)
#
#
# chain 1 |████▍     | 00:17 Iteration: 2900 / 7000 [ 41%]  (Sampling)
#
#
# chain 1 |████▌     | 00:18 Iteration: 3000 / 7000 [ 42%]  (Sampling)
#
#
# chain 1 |████▋     | 00:19 Iteration: 3100 / 7000 [ 44%]  (Sampling)
#
#
# chain 1 |████▊     | 00:19 Iteration: 3200 / 7000 [ 45%]  (Sampling)
#
#
# chain 1 |█████     | 00:20 Iteration: 3300 / 7000 [ 47%]  (Sampling)
#
#
# chain 1 |█████▏    | 00:21 Iteration: 3400 / 7000 [ 48%]  (Sampling)
#
#
# chain 1 |█████▎    | 00:21 Iteration: 3500 / 7000 [ 50%]  (Sampling)
#
#
# chain 1 |█████▍    | 00:22 Iteration: 3600 / 7000 [ 51%]  (Sampling)
#
#
# chain 1 |█████▌    | 00:23 Iteration: 3700 / 7000 [ 52%]  (Sampling)
#
#
# chain 1 |█████▋    | 00:24 Iteration: 3800 / 7000 [ 54%]  (Sampling)
# chain 1 |█████▊    | 00:24 Iteration: 3900 / 7000 [ 55%]  (Sampling)
#
#
# chain 1 |█████▉    | 00:25 Iteration: 4000 / 7000 [ 57%]  (Sampling)
#
#
# chain 1 |██████    | 00:26 Iteration: 4100 / 7000 [ 58%]  (Sampling)
#
#
# chain 1 |██████▎   | 00:26 Iteration: 4200 / 7000 [ 60%]  (Sampling)
#
#
# chain 1 |██████▍   | 00:27 Iteration: 4300 / 7000 [ 61%]  (Sampling)
#
#
# chain 1 |██████▌   | 00:28 Iteration: 4400 / 7000 [ 62%]  (Sampling)
#
#
# chain 1 |██████▋   | 00:28 Iteration: 4500 / 7000 [ 64%]  (Sampling)
#
#
# chain 1 |██████▊   | 00:29 Iteration: 4600 / 7000 [ 65%]  (Sampling)
#
#
# chain 1 |██████▉   | 00:29 Iteration: 4700 / 7000 [ 67%]  (Sampling)
#
#
# chain 1 |███████   | 00:30 Iteration: 4800 / 7000 [ 68%]  (Sampling)
#
#
# chain 1 |███████▏  | 00:31 Iteration: 4900 / 7000 [ 70%]  (Sampling)
#
#
# chain 1 |███████▎  | 00:31 Iteration: 5000 / 7000 [ 71%]  (Sampling)
#
#
# chain 1 |███████▌  | 00:32 Iteration: 5100 / 7000 [ 72%]  (Sampling)
#
#
# chain 1 |███████▋  | 00:33 Iteration: 5200 / 7000 [ 74%]  (Sampling)
#
#
# chain 1 |███████▊  | 00:33 Iteration: 5300 / 7000 [ 75%]  (Sampling)
#
#
# chain 1 |███████▉  | 00:34 Iteration: 5400 / 7000 [ 77%]  (Sampling)
#
#
# chain 1 |████████  | 00:34 Iteration: 5500 / 7000 [ 78%]  (Sampling)
#
#
# chain 1 |████████▏ | 00:35 Iteration: 5600 / 7000 [ 80%]  (Sampling)
#
#
# chain 1 |████████▎ | 00:36 Iteration: 5700 / 7000 [ 81%]  (Sampling)
#
#
#
#
# chain 1 |████████▍ | 00:36 Iteration: 5800 / 7000 [ 82%]  (Sampling)
#
#
# chain 1 |████████▌ | 00:37 Iteration: 5900 / 7000 [ 84%]  (Sampling)
#
#
# chain 1 |████████▊ | 00:37 Iteration: 6000 / 7000 [ 85%]  (Sampling)
#
#
# chain 1 |████████▉ | 00:38 Iteration: 6100 / 7000 [ 87%]  (Sampling)
#
#
# chain 1 |█████████ | 00:39 Iteration: 6200 / 7000 [ 88%]  (Sampling)
#
#
# chain 1 |█████████▏| 00:40 Iteration: 6300 / 7000 [ 90%]  (Sampling)
#
#
# chain 1 |█████████▎| 00:40 Iteration: 6400 / 7000 [ 91%]  (Sampling)
# chain 1 |█████████▍| 00:41 Iteration: 6500 / 7000 [ 92%]  (Sampling)
#
#
#
#
# chain 1 |█████████▌| 00:42 Iteration: 6600 / 7000 [ 94%]  (Sampling)
# chain 1 |█████████▋| 00:42 Iteration: 6700 / 7000 [ 95%]  (Sampling)
#
#
# chain 1 |█████████▊| 00:43 Iteration: 6800 / 7000 [ 97%]  (Sampling)
#
#
# chain 1 |██████████| 00:44 Iteration: 6900 / 7000 [ 98%]  (Sampling)
#
#
# chain 1 |██████████| 00:44 Sampling completed
# chain 2 |██████████| 00:44 Sampling completed
# chain 3 |██████████| 00:44 Sampling completed
# chain 4 |██████████| 00:44 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# "Processing csv files: /home/Lab2/samples/code_4-20230321132818_1.csv, /home/Lab2/samples/code_4-20230321132818_2.csv, /home/Lab2/samples/code_4-20230321132818_3.csv, /home/Lab2/samples/code_4-20230321132818_4.csv\n\nChecking sampler transitions treedepth.\nTreedepth satisfactory for all transitions.\n\nChecking sampler transitions for divergences.\n9489 of 24000 (39.54%) transitions ended with a divergence.\nThese divergent transitions indicate that HMC is not fully able to explore the posterior distribution.\nTry increasing adapt delta closer to 1.\nIf this doesn't remove all divergences, try to reparameterize the model.\n\nChecking E-BFMI - sampler transitions HMC potential energy.\nE-BFMI satisfactory.\n\nEffective sample size satisfactory.\n\nSplit R-hat values satisfactory all parameters.\n\nProcessing complete.\n"

# %%
N=500
xs = np.linspace(0,8,N)
pdfs = stats.gamma.pdf(xs, 1.25, scale = 1 / 1.25)

## add histogram of theta samples with 160 bins
samples_df = out_gamma1.draws_pd()
sns.histplot(samples_df, x="theta", bins=160, stat="density", label="Actual")
plt.plot(xs, pdfs, linewidth=2, label="Analytical", color='r')

plt.gca().set_xlabel("theta")
plt.gca().set_ylabel("Probability Density Function")
plt.legend()
plt.show()

# %% [markdown]
# Constrained parameter

# %%
model_gm2 = CmdStanModel(stan_file='code_5.stan')
out_gamma2 = model_gm2.sample(output_dir='samples',iter_sampling=6000,iter_warmup=1000, seed=4838282)
out_gamma2.diagnose()
# Out:
# INFO:cmdstanpy:compiling stan file /home/Lab2/code_5.stan to exe file /home/Lab2/code_5
# INFO:cmdstanpy:compiled model executable: /home/Lab2/code_5
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
#
# chain 1 |█▍        | 00:00 Iteration:  800 / 7000 [ 11%]  (Warmup)
#
#
#
#
#
#
#
#
#
#
# chain 1 |██        | 00:03 Iteration: 1200 / 7000 [ 17%]  (Sampling)
#
#
#
#
#
#
#
#
# chain 1 |██▌       | 00:06 Iteration: 1500 / 7000 [ 21%]  (Sampling)
#
#
#
#
#
# chain 1 |██▊       | 00:07 Iteration: 1700 / 7000 [ 24%]  (Sampling)
#
#
# chain 1 |██▉       | 00:08 Iteration: 1800 / 7000 [ 25%]  (Sampling)
#
#
# chain 1 |███       | 00:08 Iteration: 1900 / 7000 [ 27%]  (Sampling)
#
#
# chain 1 |███▏      | 00:09 Iteration: 2000 / 7000 [ 28%]  (Sampling)
#
#
# chain 1 |███▎      | 00:09 Iteration: 2100 / 7000 [ 30%]  (Sampling)
#
#
# chain 1 |███▍      | 00:10 Iteration: 2200 / 7000 [ 31%]  (Sampling)
#
#
# chain 1 |███▌      | 00:11 Iteration: 2300 / 7000 [ 32%]  (Sampling)
#
#
# chain 1 |███▊      | 00:11 Iteration: 2400 / 7000 [ 34%]  (Sampling)
#
#
# chain 1 |███▉      | 00:12 Iteration: 2500 / 7000 [ 35%]  (Sampling)
#
#
# chain 1 |████      | 00:13 Iteration: 2600 / 7000 [ 37%]  (Sampling)
#
#
# chain 1 |████▏     | 00:13 Iteration: 2700 / 7000 [ 38%]  (Sampling)
#
#
# chain 1 |████▎     | 00:14 Iteration: 2800 / 7000 [ 40%]  (Sampling)
#
#
# chain 1 |████▍     | 00:15 Iteration: 2900 / 7000 [ 41%]  (Sampling)
#
#
# chain 1 |████▌     | 00:15 Iteration: 3000 / 7000 [ 42%]  (Sampling)
#
#
# chain 1 |████▋     | 00:16 Iteration: 3100 / 7000 [ 44%]  (Sampling)
#
#
# chain 1 |████▊     | 00:16 Iteration: 3200 / 7000 [ 45%]  (Sampling)
#
#
# chain 1 |█████     | 00:17 Iteration: 3300 / 7000 [ 47%]  (Sampling)
#
#
# chain 1 |█████▏    | 00:17 Iteration: 3400 / 7000 [ 48%]  (Sampling)
#
#
# chain 1 |█████▎    | 00:18 Iteration: 3500 / 7000 [ 50%]  (Sampling)
#
#
# chain 1 |█████▍    | 00:19 Iteration: 3600 / 7000 [ 51%]  (Sampling)
#
#
# chain 1 |█████▌    | 00:19 Iteration: 3700 / 7000 [ 52%]  (Sampling)
#
#
# chain 1 |█████▋    | 00:20 Iteration: 3800 / 7000 [ 54%]  (Sampling)
#
#
# chain 1 |█████▊    | 00:21 Iteration: 3900 / 7000 [ 55%]  (Sampling)
#
#
# chain 1 |█████▉    | 00:21 Iteration: 4000 / 7000 [ 57%]  (Sampling)
#
#
# chain 1 |██████    | 00:22 Iteration: 4100 / 7000 [ 58%]  (Sampling)
#
#
# chain 1 |██████▎   | 00:23 Iteration: 4200 / 7000 [ 60%]  (Sampling)
#
#
# chain 1 |██████▍   | 00:23 Iteration: 4300 / 7000 [ 61%]  (Sampling)
#
#
# chain 1 |██████▌   | 00:24 Iteration: 4400 / 7000 [ 62%]  (Sampling)
#
#
# chain 1 |██████▋   | 00:24 Iteration: 4500 / 7000 [ 64%]  (Sampling)
#
#
#
# chain 1 |██████▊   | 00:25 Iteration: 4600 / 7000 [ 65%]  (Sampling)
#
# chain 1 |██████▉   | 00:26 Iteration: 4700 / 7000 [ 67%]  (Sampling)
#
#
# chain 1 |███████   | 00:26 Iteration: 4800 / 7000 [ 68%]  (Sampling)
#
#
# chain 1 |███████▏  | 00:27 Iteration: 4900 / 7000 [ 70%]  (Sampling)
#
#
# chain 1 |███████▎  | 00:28 Iteration: 5000 / 7000 [ 71%]  (Sampling)
#
#
# chain 1 |███████▌  | 00:28 Iteration: 5100 / 7000 [ 72%]  (Sampling)
#
#
# chain 1 |███████▋  | 00:29 Iteration: 5200 / 7000 [ 74%]  (Sampling)
#
#
# chain 1 |███████▊  | 00:29 Iteration: 5300 / 7000 [ 75%]  (Sampling)
#
#
# chain 1 |███████▉  | 00:30 Iteration: 5400 / 7000 [ 77%]  (Sampling)
#
#
#
# chain 1 |████████  | 00:31 Iteration: 5500 / 7000 [ 78%]  (Sampling)
#
#
# chain 1 |████████▏ | 00:31 Iteration: 5600 / 7000 [ 80%]  (Sampling)
#
#
# chain 1 |████████▎ | 00:32 Iteration: 5700 / 7000 [ 81%]  (Sampling)
#
#
# chain 1 |████████▍ | 00:32 Iteration: 5800 / 7000 [ 82%]  (Sampling)
#
#
# chain 1 |████████▌ | 00:33 Iteration: 5900 / 7000 [ 84%]  (Sampling)
#
#
# chain 1 |████████▊ | 00:33 Iteration: 6000 / 7000 [ 85%]  (Sampling)
#
#
# chain 1 |████████▉ | 00:34 Iteration: 6100 / 7000 [ 87%]  (Sampling)
#
#
# chain 1 |█████████ | 00:35 Iteration: 6200 / 7000 [ 88%]  (Sampling)
#
#
# chain 1 |█████████▏| 00:35 Iteration: 6300 / 7000 [ 90%]  (Sampling)
#
#
# chain 1 |█████████▎| 00:36 Iteration: 6400 / 7000 [ 91%]  (Sampling)
#
#
# chain 1 |█████████▍| 00:37 Iteration: 6500 / 7000 [ 92%]  (Sampling)
#
#
# chain 1 |█████████▌| 00:37 Iteration: 6600 / 7000 [ 94%]  (Sampling)
#
# chain 1 |█████████▋| 00:38 Iteration: 6700 / 7000 [ 95%]  (Sampling)
#
#
#
# chain 1 |█████████▊| 00:38 Iteration: 6800 / 7000 [ 97%]  (Sampling)
#
#
# chain 1 |██████████| 00:39 Iteration: 6900 / 7000 [ 98%]  (Sampling)
#
# chain 1 |██████████| 00:39 Sampling completed
# chain 2 |██████████| 00:39 Sampling completed
# chain 3 |██████████| 00:39 Sampling completed
# chain 4 |██████████| 00:39 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# "Processing csv files: /home/Lab2/samples/code_5-20230321133230_1.csv, /home/Lab2/samples/code_5-20230321133230_2.csv, /home/Lab2/samples/code_5-20230321133230_3.csv, /home/Lab2/samples/code_5-20230321133230_4.csv\n\nChecking sampler transitions treedepth.\nTreedepth satisfactory for all transitions.\n\nChecking sampler transitions for divergences.\n2 of 24000 (0.01%) transitions ended with a divergence.\nThese divergent transitions indicate that HMC is not fully able to explore the posterior distribution.\nTry increasing adapt delta closer to 1.\nIf this doesn't remove all divergences, try to reparameterize the model.\n\nChecking E-BFMI - sampler transitions HMC potential energy.\nE-BFMI satisfactory.\n\nEffective sample size satisfactory.\n\nSplit R-hat values satisfactory all parameters.\n\nProcessing complete.\n"

# %%
N=500
xs = np.linspace(0,8,N)
pdfs = stats.gamma.pdf(xs, 1.25, scale = 1 / 1.25) 


## add histogram of theta samples from the second model with 160 bins
samples_df = out_gamma2.draws_pd()
sns.histplot(samples_df, x="theta", bins=160, stat="density", label="Actual")
plt.plot(xs, pdfs, linewidth=2, label="Analytical", color='r')

plt.gca().set_xlabel("theta")
plt.gca().set_ylabel("Probability Density Function")
plt.legend()
plt.show()

# %% [markdown]
# I dont really see any changes with or without parameter constraints
#
# # Ex. 4. Functions and different functionalities of stan

# %%
model_tune = CmdStanModel(stan_file='code_6.stan')

F = 6
L = 5
y0 = 2

data={'y_guess':[y0],
        'theta':[(F+L)/2]}
tunes = model_tune.sample(data=data, fixed_param=True, iter_sampling=1, iter_warmup=0, chains = 1)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
found_sigma = tunes.draws_pd()["sigma"][0]
print("Found sigma: ", found_sigma)
# Out:
# Found sigma:  2.13523

# %% [markdown]
# # Ex. 5. Different methods of defining models

# %%
model_samp_st = CmdStanModel(stan_file='code_7.stan')
model_log_target = CmdStanModel(stan_file='code_8.stan')
model_log_target_ind = CmdStanModel(stan_file='code_9.stan')
data = {'N': F}
seed = 8022000 #integer, your date of birth in the DDMMYYYY format without leading zero (or if you are GPRD weary, use any other date you wish)
result_1 = model_samp_st.sample(data=data,seed=seed)
result_2 = model_log_target.sample(data=data,seed=seed)
result_3 = model_log_target_ind.sample(data=data,seed=seed)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |██████▎   | 00:00 Iteration: 1100 / 2000 [ 55%]  (Sampling)
#
#
#
#
# chain 1 |█████████ | 00:00 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
#
#
# chain 1 |██████████| 00:01 Sampling completed
# chain 2 |██████████| 00:01 Sampling completed
# chain 3 |██████████| 00:01 Sampling completed
#
#
# chain 4 |██████████| 00:01 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▍         | 00:00 Status
# chain 1 |█████▉    | 00:00 Iteration: 1001 / 2000 [ 50%]  (Sampling)
#
#
#
#
#
# chain 1 |█████████▌| 00:00 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |▉         | 00:00 Iteration:    1 / 2000 [  0%]  (Warmup)
#
#
#
# chain 1 |██████▊   | 00:00 Iteration: 1200 / 2000 [ 60%]  (Sampling)
#
#
#
#
#
# chain 1 |█████████▌| 00:01 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
# chain 1 |██████████| 00:01 Sampling completed
# chain 2 |██████████| 00:01 Sampling completed
# chain 3 |██████████| 00:01 Sampling completed
# chain 4 |██████████| 00:01 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
az.plot_density([result_1,result_2,result_3])
plt.show()

# %% [markdown]
# # Ex. 6. Generated quantities post sampling

# %%
model_gq = CmdStanModel(stan_file='code_10.stan')
# fill in with chosen result from previous excercise
mean_of_y = model_gq.generate_quantities(data=data,
                                        mcmc_sample = result_3)
# investigate the output and plot histogram of mean_y variable
# Out:
# INFO:cmdstanpy:compiling stan file /home/Lab2/code_10.stan to exe file /home/Lab2/code_10
# INFO:cmdstanpy:compiled model executable: /home/Lab2/code_10
# WARNING:cmdstanpy:Stan compiler has produced 1 warnings:
# WARNING:cmdstanpy:
# --- Translating Stan model to C++ code ---
# bin/stanc  --o=/home/Lab2/code_10.hpp /home/Lab2/code_10.stan
# Warning in '/home/Lab2/code_10.stan', line 6, column 4: Declaration of arrays
#     by placing brackets after a variable name is deprecated and will be
#     removed in Stan 2.32.0. Instead use the array keyword before the type.
#     This can be changed automatically using the auto-format flag to stanc
#
# --- Compiling, linking C++ code ---
# g++ -std=c++1y -pthread -D_REENTRANT -Wno-sign-compare -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.75.0 -I stan/lib/stan_math/lib/sundials_6.0.0/include -I stan/lib/stan_math/lib/sundials_6.0.0/src/sundials    -DBOOST_DISABLE_ASSERTS          -c -Wno-ignored-attributes   -x c++ -o /home/Lab2/code_10.o /home/Lab2/code_10.hpp
# g++ -std=c++1y -pthread -D_REENTRANT -Wno-sign-compare -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.75.0 -I stan/lib/stan_math/lib/sundials_6.0.0/include -I stan/lib/stan_math/lib/sundials_6.0.0/src/sundials    -DBOOST_DISABLE_ASSERTS                -Wl,-L,"/opt/cmdstan-2.29.0/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"/opt/cmdstan-2.29.0/stan/lib/stan_math/lib/tbb"      /home/Lab2/code_10.o src/cmdstan/main.o        -Wl,-L,"/opt/cmdstan-2.29.0/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"/opt/cmdstan-2.29.0/stan/lib/stan_math/lib/tbb"   stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_nvecserial.a stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_cvodes.a stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_idas.a stan/lib/stan_math/lib/sundials_6.0.0/lib/libsundials_kinsol.a  stan/lib/stan_math/lib/tbb/libtbb.so.2 -o /home/Lab2/code_10
# rm -f /home/Lab2/code_10.o
#
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [2] start processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [2] done processing
# INFO:cmdstanpy:Chain [4] start processing
# INFO:cmdstanpy:Chain [3] start processing
# INFO:cmdstanpy:Chain [4] done processing
# INFO:cmdstanpy:Chain [3] done processing

# %%
mean_of_y_df = mean_of_y.draws_pd()
sns.histplot(mean_of_y_df)
plt.show()
